# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from tqdm import tqdm_notebook
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import selenium.webdriver.support.expected_conditions as EC
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

# %%
driver = webdriver.Chrome(r'C:\Users\venug\Downloads\chromedriver.exe')

# %%
driver.get('https://dynamics.pharmaview.dk/ords/f?p=300:101')

# %%
driver.find_element_by_id("P101_USERNAME").send_keys('amgsaga')
driver.find_element_by_id("P101_PASSWORD").send_keys('amgsaga')
driver.find_element_by_id('P101_LOGIN').click()
timeout = 500
locator = '//*[@id="direct_menu_menubar_2i"]'
WebDriverWait(driver, timeout).until(EC.visibility_of_element_located((By.XPATH, locator)))
driver.find_element_by_id("direct_menu_menubar_2i").click()
timeout = 500
locator = '//*[@id="15813645532759790_orig"]'
WebDriverWait(driver, timeout).until(EC.visibility_of_element_located((By.XPATH, locator)))
data = driver.page_source
# dataParsed = BeautifulSoup(data,'lxml')
# Masterdf = pd.DataFrame()
driver.find_element_by_id('data_sheet_daily_actions_button').click()
time.sleep(1)
driver.find_element_by_id("data_sheet_daily_actions_menu_14i").click()
time.sleep(5)
driver.find_element_by_id("data_sheet_daily_download_CSV").click()

# %%
# time.sleep(1)
# driver.find_element_by_id("data_sheet_daily_actions_menu_3_0_c9i").click()

# %%
# dataParsed = BeautifulSoup(data,'lxml')
# dataParsed.find('span',class_ = 'a-IRR-pagination-label').text.replace(" ","").split("-")[0]
# Out:
# '1'

# %%
int(driver.find_element(By.XPATH,'//*[@id="data_sheet_daily_data_panel"]/div[2]/ul/li[2]/span').text.replace(" ","").split("-")[0])
# Out:
# 101

# %%
# prev = 1
# while(1):
#     try:
#         driver.find_element(By.XPATH,'//*[@id="data_sheet_daily_data_panel"]/div[2]/ul/li[3]/button').click()
#     except:
#         break
#     time.sleep(5)
#     timeout = 500
#     WebDriverWait(driver, timeout).until(int(driver.find_element(By.XPATH,'//*[@id="data_sheet_daily_data_panel"]/div[2]/ul/li[2]/span').text.replace(" ","").split("-")[0])==prev+50)
#     prev+=50
#     df1 = pd.read_html(driver.page_source)
#     Masterdf = Masterdf.append(df1[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-fb07dbff05a1> in <module>
#       7     time.sleep(5)
#       8     timeout = 500
# ----> 9     WebDriverWait(driver, timeout).until(int(driver.find_element(By.XPATH,'//*[@id="data_sheet_daily_data_panel"]/div[2]/ul/li[2]/span').text.replace(" ","").split("-")[0])==prev+50)
#      10     prev+=50
#      11     df1 = pd.read_html(driver.page_source)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      69         while True:
#      70             try:
# ---> 71                 value = method(self._driver)
#      72                 if value:
#      73                     return value
#
# TypeError: 'bool' object is not callable

# %%
Masterdf.tail()
# Out:
#    PeriodAscending                                  Package text long  \
# 45      10-03-2020  Aranesp inj.væske, opl., pen 150 mikrogram 0,3...
# 46      10-03-2020  Aranesp inj.væske, opl., pen 500 mikrogram 1,0...
# 47      10-03-2020  Aranesp inj.væske, opl., pen 300 mikrogram 0,6...
# 48      10-03-2020  Mimpara Filmovertrukne tabl. 60 mg 28 stk. (2 ...
# 49      10-03-2020  Mimpara Filmovertrukne tabl. 90 mg 28 stk. (2 ...
#
#     Product  Volume     Value
# 45  Aranesp      20  46.78740
# 46  Aranesp       2  15.59586
# 47  Aranesp      20  93.57520
# 48  Mimpara       3   7.58439
# 49  Mimpara      24  91.01256

# %%
df1 = pd.read_html(data)
Masterdf = Masterdf.append(df1[1])
Masterdf
# Out:
#    PeriodAscending                                  Package text long  \
# 0       02-03-2020  Xgeva Inj.væske, opløsning 120 mg 1 stk. (1,7 ...
# 1       02-03-2020  Parsabiv Inj.væske, opløsning 2,5 mg 6 stk. AM...
# 2       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (P...
# 3       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. AM...
# 4       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (O...
# 5       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (A...
# 6       02-03-2020  Aranesp Inj.vsk,opl.,sprøjte 20 mikrogram 4x0,...
# 7       02-03-2020  Aranesp Inj.vsk,opl.,sprøjte 30 mikrogram 4x0,...
# 8       02-03-2020  Aranesp Inj.vsk,opl.,sprøjte 150 mikrogram 4 x...
# 9       02-03-2020  Aranesp Inj.vsk,opl.,sprøjte 300 mikrogram 1x0...
# 10      02-03-2020  Aranesp inj.væske, opl., pen 150 mikrogram 0,3...
# 11      02-03-2020  Aranesp inj.væske, opl., pen 300 mikrogram 0,6...
# 12      02-03-2020  Mimpara Filmovertrukne tabl. 90 mg 28 stk. (2 ...
# 13      02-03-2020  Mimpara Filmovertrukne tabl. 30 mg 28 stk. (2 ...
# 14      02-03-2020  Mimpara Filmovertrukne tabl. 30 mg 28 stk. (bl...
# 15      02-03-2020  Repatha inj.væske, opl., pen 140 mg 6 stk. AMG...
# 16      02-03-2020  AMGEVITA inj.væske, opl., pen 40 mg 2 stk. AMG...
# 17      02-03-2020  Nplate Pulv.t.inj.væske,opl 250 mikrogram 1 ht...
# 18      03-03-2020  Xgeva Inj.væske, opløsning 120 mg 1 stk. (1,7 ...
# 19      03-03-2020  Vectibix Konc.t.inf.væsk.opl. 20 mg/ml 5 ml AM...
# 20      03-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (P...
# 21      03-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. AM...
# 22      03-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (2...
# 9    Aranesp      58    271.36808
# 10   Aranesp      20     46.78740
# 11   Aranesp      40    187.15040
# 12   Mimpara       2      7.58438
# 13   Mimpara      17     23.27980
# 14   Mimpara       3      4.10523
# 15   Repatha       6     58.11792
# 16  AMGEVITA      50    244.65350
# 17    Nplate      16     57.21088
# 18     Xgeva      10     21.01880
# 19  Vectibix      10     28.60540
# 20    Prolia      -1     -1.81600
# 21    Prolia      22     39.91812
# 22    Prolia      10     17.74370
# 23    Prolia       5      8.90890
# 24    Prolia      76    133.72504
# 25   Aranesp      10      6.23810
# 26   Aranesp      10     18.71470
# 27   Aranesp      48    119.77728
# 28   Aranesp      45    140.36175
# 29   Aranesp      15     93.57540
# 30   Aranesp       5     46.78785
# 31   Aranesp      20     93.57520
# 32   Aranesp      60    140.36220
# 33   Aranesp      20     93.57520
# 34   Mimpara      11     27.80943
# 35   Mimpara      35     47.92900
# 36   Mimpara       8     10.94728
# 37   Mimpara       1      1.36841
# 38  Kyprolis       6      8.65686
# 39  Neupogen       3      8.28816
# 40  Vectibix      10    114.42340
# 41    Nplate      10     35.75680
# 42     Xgeva      42     88.27896
# 43  Parsabiv      10     12.19080
# 44    Prolia       2      3.62892
# 45    Prolia       8     14.19496
# 46    Prolia      40     71.27120
# 47    Prolia      88    154.83952
# 48   Aranesp       2      1.24762
# 49   Aranesp      20     24.95360

# %%
# Out:
#    PeriodAscending                                  Package text long  \
# 0       02-03-2020  Xgeva Inj.væske, opløsning 120 mg 1 stk. (1,7 ...
# 1       02-03-2020  Parsabiv Inj.væske, opløsning 2,5 mg 6 stk. AM...
# 2       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (P...
# 3       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. AM...
# 4       02-03-2020  Prolia Inj.væske, opløsning 60 mg/ml 1 stk. (O...
# ..             ...                                                ...
# 45      10-03-2020  Aranesp inj.væske, opl., pen 150 mikrogram 0,3...
# 46      10-03-2020  Aranesp inj.væske, opl., pen 500 mikrogram 1,0...
# 47      10-03-2020  Aranesp inj.væske, opl., pen 300 mikrogram 0,6...
# 48      10-03-2020  Mimpara Filmovertrukne tabl. 60 mg 28 stk. (2 ...
# 49      10-03-2020  Mimpara Filmovertrukne tabl. 90 mg 28 stk. (2 ...
#
#      Product  Volume        Value
# 0      Xgeva      40     84.07520
# 1   Parsabiv       1  60952.00000
# 2     Prolia       1      1.81600
# 3     Prolia       3      5.44338
# 4     Prolia       6     10.69068
# ..       ...     ...          ...
# 45   Aranesp      20     46.78740
# 46   Aranesp       2     15.59586
# 47   Aranesp      20     93.57520
# 48   Mimpara       3      7.58439
# 49   Mimpara      24     91.01256
#
# [1050 rows x 5 columns]
